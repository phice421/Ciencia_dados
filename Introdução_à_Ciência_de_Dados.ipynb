# %% [markdown]
# <a href="https://colab.research.google.com/github/phice421/Ciencia_dados/blob/main/Introdu%C3%A7%C3%A3o_%C3%A0_Ci%C3%AAncia_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Carregando arquivos de dados csv no Colaboratory:

# %% [markdown]
# ## Arquivos csv:

# %% [markdown]
# Antes de carregar o seu arquivo csv certifique-se qual o tipo de separação entre as colunas que foi aplicado no arquivo. Para isso, basta abrir o mesmo num bloco de notas e checar como a separação está sendo feita. Na imagem abaixo podemos ver que o fixed acidity, volatile acidity e outros estão separados por virgulas. Logo os dados tem suas colunas separadas por vírgulas.
#
#
#
# ![Arquivos csv](https://drive.google.com/uc?export=view&id=1F30nwQ0s5Tz0DgJTsr8oyIga6NEbmN29)

# %% [markdown]
# Na sequência verifique se a codificação do arquivo está no padrão UTF-8. Para isso, clique em Arquivo, Salvar Como e verifique o padrão em Codificação.
#
#
# ![Arquivos csv](https://drive.google.com/uc?export=view&id=1yQ-fIAfzs1sVfbcT24surQomWGYb41Bu)

# %% [markdown]
# Faça o upload do seu arquivo csv no Google Drive. Compartilhe o arquivo com a permissão para edição. Após isso, copie o link de compartilhamento, vamos precisar dele para carregar o arquivo:

# %% [markdown]
# ![Arquivos csv](https://drive.google.com/uc?export=view&id=10-ST-ft2ndyMxLXxEytkiBGcXviiMeGa)

# %% [markdown]
# ## Recebendo dados em csv:

# %% [markdown]
# Agora iremos carregar os nossos dados com o auxílio da biblioteca Pandas. Essa biblioteca nos permite visualizar os dados de forma tabular. Para isso faça o upload dos seus arquivos na pasta ao lado no próprio Google Colab:

# %% [markdown]
# ![Arquivos csv](https://drive.google.com/uc?export=view&id=107K0o-Q3_HCsqOhOeFeSSh2g-Tsr_EQZ)

# %% [markdown]
# ### Opção 1: Carregando os arquivos importando o documento na sessão do Google Colab.

# %% [markdown]
# Vamos agora carregar o arquivo csv com o pandas. Para isso, iremos usar o comando `import pandas as pd` para carregar a biblioteca do pandas e iremos "apelidar" ela de pd.
#
# Na sequência iremos usar o comando `pd.read_csv("Nome_do_Arquivo", sep = 'tipo_separador_coluna')`, sendo que:
#
#
#
# *   `Nome_do_Arquivo`: É o nome do arquivo incluindo a pasta que ele se encontra. No nosso caso como o arquivo está na pasta raiz do Colab, preencheremos esse parâmetro com "Vinho.csv".
# *   `sep = tipo_separador_coluna`: Iremos mudar esse parâmetro para o tipo de separador do nosso arquivo csv. No nosso caso vimos que o separador é a vírgula.

# %%
# Importando o pandas
import pandas as pd

# Recebendo os dados:
from google_drive_downloader import GoogleDriveDownloader as gdd

data_google_id = '1jFxSqBKQVUM9FXsNLrpC6kLhnQQnN9ca'
gdd.download_file_from_google_drive(file_id=data_google_id,
                                    dest_path = './vinho.csv', # Faz o download dos dados e salva o mesmo num arquivo nomeado data.csv
                                    showsize = True)

# Armazenandos os dados em um DataFrame
dados = pd.read_csv("vinho.csv")

# %% [markdown]
# Acima carregamos na variável `dados` o arquivo Vinho.csv. Agora podemos visualizar o arquivo csv se assim desejarmos:

# %%
dados
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# ### Opção 2: Carregando os arquivos direto do seu Google Drive:

# %% [markdown]
# Poderíamos usar o Colab para alguma atividade em grupo onde todos podem usar o mesmo arquivo compartilhado. Para isso, faça o upload do seu arquivo csv no Google Drive. Compartilhe o arquivo com a permissão para edição. Após isso, copie o link de compartilhamento, pois vamos precisar dele para carregar o arquivo

# %% [markdown]
# Dessa vez iremos usar outra biblioteca para nos ajudar a carregar o arquivo. Para isso iremos importar `GoogleDriveDownloader` usando o comando: `from google_drive_downloader import GoogleDriveDownloader as gdd`. Faremos isso com o seguinte comando: `from google_drive_downloader import GoogleDriveDownloader as gdd`
#
# Para que o nosso código consiga fazer o download do arquivo no Google Drive iremos usar o seguinte código após importar a biblioteca:
#
#
#
# ```
# gdd.download_file_from_google_drive(file_id=data_google_id,
#                                     dest_path = './nome_arquivo.csv',
#                                     showsize = valor_booleano)
# ```
# Os argumentos dessa função são:
#
#
#
# *   `file_id=data_google_id`: Passamos aqui o id do compartilhamento do arquivo salvo no Google Drive
# *   `dest_path = './nome_arquivo.csv`: Informamos aqui onde desejamos salver o arquivo, podemos até escolher uma pasta para salvá-lo
# *   `showsize = valor_booleano`: Aqui podemos incluir apenas dois valores possíveis `True` ou `False`. Se inserirmos `True`, iremos ver que durante a execução da célula irá aparecer uma mensagem contendo informações do download do arquivo, do contrário isso não irá aparecer.

# %%
# Importando o pandas
import pandas as pd

# Recebendo os dados:
from google_drive_downloader import GoogleDriveDownloader as gdd

# Criando uma variável com o id do Arquivo no Google Drive
data_google_id = '1-rAoUEXCSrTKy8z-rA_K60-D3YjAUTTO'

## Fazendo o download do arquivo no Google Drive
gdd.download_file_from_google_drive(file_id=data_google_id, # file_id deve receber o id do seu arquivo no Google Drive
                                    dest_path = './dados_google_drive.csv', # Faz o download dos dados e salva o mesmo num arquivo nomeado dados.csv
                                    showsize = True)

# Carregando o arquivo numa nova variavel:
dados_drive = pd.read_csv("dados_google_drive.csv", sep = ',')

# %% [markdown]
# O arquivo acima está disponível no link: https://drive.google.com/file/d/1-rAoUEXCSrTKy8z-rA_K60-D3YjAUTTO/view?usp=sharing, este link você pode obter quando está compartilhando o seu arquivo, assim como fizemos anteriormente. Repare que o '1-rAoUEXCSrTKy8z-rA_K60-D3YjAUTTO' é uma parte do link acima e é a parte do link que nos interessa.

# %% [markdown]
# Agora carregamos na variável `dados_drive` o arquivo Vinho.csv só que fizemos o download do arquivo do nosso Google Drive. Agora podemos visualizar o arquivo csv se assim desejarmos:

# %%
dados_drive
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# # Comandos básicos de visulização de dados (Pandas)

# %% [markdown]
# Aqui iremos aprender um pouco sobre o Pandas para que em problemas futuros seja possível conhecer algumas possíveis soluções usando essa API.

# %% [markdown]
# Vamos inicializar vendo o tipo dos dados que foram carregados anteriormente. Vamos analisar a tabela que salvamos em `dados`

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Um DataFrame é uma tabela bidimensional contendo linhas e colunas. Por ser um classe do pandas, essa tabela possui diversos métodos e atributos. Veremos alguns deles a seguir:

# %% [markdown]
# O método `head` permite que seja visualizado, por padrão, as 5 primeiras linhas dos nossos dados.

# %%
# visualizar as 5 primeiras linha
dados.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# Enquanto que o método `tail` permite que seja vizualizado, por padrão, as 5 últimas linhas dos nossos dados.

# %%
# últimas linhas
dados.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %% [markdown]
# Podemos checar os tipos de dados envolvidos no nosso problema com a função `info()`:

# %%
# tipos de dados
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# Os principais tipos de dados que o pandas pode nos retornar são:
#
# Pandas | Tipo de dados | Uso
# ---|---|---
# object | string ou vários tipos | Texto ou conjunto de texto
# int64 | inteiro | Valores inteiros
# float64 | real | Valores reais (números com casas decimais)
# bool | boleano | Valores que assumem apenas Verdadeiro ou Falso

# %% [markdown]
# Podemos também verificar quantas linhas e colunas temos nos nossos dados analisando o atributo `shape`

# %%
# tamanho dos dados
dados.shape
# Out:
# (1599, 12)

# %% [markdown]
# ## Filtrando os dados

# %% [markdown]
# Podemos filtrar os dados do nosso dataset para acessar algumas linhas ou colunas dele. Nas seções a seguir iremos trabalhar alguns desses exemplos:

# %% [markdown]
# ### Filtrando os dados a partir das suas colunas

# %% [markdown]
# *   É possível filtrar uma coluna inteira da tabela usando `df.nomeDaColuna`

# %%
dados.alcohol
# Out:
# 0        9.4
# 1        9.8
# 2        9.8
# 3        9.8
# 4        9.4
#         ...
# 1594    10.5
# 1595    11.2
# 1596    11.0
# 1597    10.2
# 1598    11.0
# Name: alcohol, Length: 1599, dtype: float64

# %% [markdown]
# Quando temos apenas uma coluna de dados, o tipo de dado é Series:

# %%
A = dados.alcohol
type(A)
# Out:
# pandas.core.series.Series

# %%
A
# Out:
# 0        9.4
# 1        9.8
# 2        9.8
# 3        9.8
# 4        9.4
#         ...
# 1594    10.5
# 1595    11.2
# 1596    11.0
# 1597    10.2
# 1598    11.0
# Name: alcohol, Length: 1599, dtype: float64

# %% [markdown]
# *   Dessa forma não conseguimos selecionar colunas que tenham espaços em seu nome. Uma forma de resolver isso é com o `df['nomeDaColuna']`

# %%
# Selecionando apenas uma coluna
dados["residual sugar"]
# Out:
# 0       1.9
# 1       2.6
# 2       2.3
# 3       1.9
# 4       1.9
#        ...
# 1594    2.0
# 1595    2.2
# 1596    2.3
# 1597    2.0
# 1598    3.6
# Name: residual sugar, Length: 1599, dtype: float64

# %% [markdown]
# Podemos também informar uma lista com o nome das colunas que desejamos filtrar para visualizar apenas essas colunas. Para isso usamos `nome_dataframe[["coluna_1", "coluna_2", "coluna_3", ..., "coluna_n"]]`

# %%
#Podemos passar uma lista das colunas que desejamos selecionar
dados[["fixed acidity","residual sugar","citric acid"]]
# Out:
#       fixed acidity  residual sugar  citric acid
# 0               7.4             1.9         0.00
# 1               7.8             2.6         0.00
# 2               7.8             2.3         0.04
# 3              11.2             1.9         0.56
# 4               7.4             1.9         0.00
# ...             ...             ...          ...
# 1594            6.2             2.0         0.08
# 1595            5.9             2.2         0.10
# 1596            6.3             2.3         0.13
# 1597            5.9             2.0         0.12
# 1598            6.0             3.6         0.47
#
# [1599 rows x 3 columns]

# %% [markdown]
# É possível criar uma variável nova apenas com esse DataFrame:

# %%
C = dados[["fixed acidity","residual sugar","citric acid"]]
C.head()
# Out:
#    fixed acidity  residual sugar  citric acid
# 0            7.4             1.9         0.00
# 1            7.8             2.6         0.00
# 2            7.8             2.3         0.04
# 3           11.2             1.9         0.56
# 4            7.4             1.9         0.00

# %% [markdown]
# *   Podemos também selecionar os dados a partir dos **números das linhas e de suas colunas** usando o método `iloc` usando `nome_dataframe.iloc[linha,coluna]`

# %%
#Filtrando pelos números de linhas e colunas
# linha 0, coluna 1
dados.iloc[0, 1]
# Out:
# 0.7

# %% [markdown]
# Para selecionar linhas e colunas especificas, podemos usar `nome_dataframe.iloc[[[linha_1, linha_2],[coluna_1, coluna_2]]`

# %%
#Selecionando linhas e colunas especificas
dados.iloc[[1,4], [1,5]]
# Out:
#    volatile acidity  free sulfur dioxide
# 1              0.88                 25.0
# 4              0.70                 11.0

# %% [markdown]
# Para selecionar intervalos de linhas ou colunas podemos usar `nome_dataframe[[linha_inicio:linha_fim],[coluna_inicio:coluna_fim]]`

# %%
#Selecionando um intervalo de linhas e duas colunas
dados.iloc[0:10, [1,5]]
# Out:
#    volatile acidity  free sulfur dioxide
# 0              0.70                 11.0
# 1              0.88                 25.0
# 2              0.76                 15.0
# 3              0.28                 17.0
# 4              0.70                 11.0
# 5              0.66                 13.0
# 6              0.60                 15.0
# 7              0.65                 15.0
# 8              0.58                  9.0
# 9              0.50                 17.0

# %% [markdown]
# *   Também é possível selecionar os dados a partir dos **números de suas linhas NOMES das suas colunas** usando o método `loc`. Para isso, devemos usar: `dados.loc[:, ["nome_coluna_1", "nome_coluna_2", "nome_coluna_3", ..., "nome_coluna_3]`

# %%
# Acessando todos os dados das colunas X1 e X5
dados.loc[:,["fixed acidity","residual sugar","citric acid"]]
# Out:
#       fixed acidity  residual sugar  citric acid
# 0               7.4             1.9         0.00
# 1               7.8             2.6         0.00
# 2               7.8             2.3         0.04
# 3              11.2             1.9         0.56
# 4               7.4             1.9         0.00
# ...             ...             ...          ...
# 1594            6.2             2.0         0.08
# 1595            5.9             2.2         0.10
# 1596            6.3             2.3         0.13
# 1597            5.9             2.0         0.12
# 1598            6.0             3.6         0.47
#
# [1599 rows x 3 columns]

# %% [markdown]
# Para acessar um intervalo de linhas usando o iloc, basta seguir os exemplos anteriores `dados.loc[num_inicio:num_fim,"nome_coluna_1:nome_coluna_2]`

# %%
# Acessando um intervalo de dados das colunas X1 até X4
dados.loc[10:20,"chlorides":"pH"]
# Out:
#     chlorides  free sulfur dioxide  total sulfur dioxide  density    pH
# 10      0.097                 15.0                  65.0   0.9959  3.28
# 11      0.071                 17.0                 102.0   0.9978  3.35
# 12      0.089                 16.0                  59.0   0.9943  3.58
# 13      0.114                  9.0                  29.0   0.9974  3.26
# 14      0.176                 52.0                 145.0   0.9986  3.16
# 15      0.170                 51.0                 148.0   0.9986  3.17
# 16      0.092                 35.0                 103.0   0.9969  3.30
# 17      0.368                 16.0                  56.0   0.9968  3.11
# 18      0.086                  6.0                  29.0   0.9974  3.38
# 19      0.341                 17.0                  56.0   0.9969  3.04
# 20      0.077                 29.0                  60.0   0.9968  3.39

# %% [markdown]
# ### Filtrando os dados a partir de mascaras.

# %% [markdown]
# *   É possível filtrar os dados com o uso de valores booleanos `[True,False]`. Onde quando o valor de uma linha é `True`, a mesma será exibida e se o valor é `False` o valor será ocultado.

# %% [markdown]
# Vamos criar um filtro para valores de "free sulfur dioxide">=20:

# %%
#Criando uma mascara com valores maiores ou iguais a 20
dados["free sulfur dioxide"] >=20
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1594     True
# 1595     True
# 1596     True
# 1597     True
# 1598    False
# Name: free sulfur dioxide, Length: 1599, dtype: bool

# %% [markdown]
# Vamos ver outro filtro para "quality" ==5

# %%
#Criando uma mascara para valores iguais a 5
dados["quality"] == 5
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1594     True
# 1595    False
# 1596    False
# 1597     True
# 1598    False
# Name: quality, Length: 1599, dtype: bool

# %% [markdown]
# Podemos também expressar lógicas E (`&`) e OU (`|`). Vamos ver o caso onde o "ph">=3.4 e o "free sulfur dioxide" >=10:

# %%
(dados["pH"] >= 3.4) & (dados["free sulfur dioxide"] >=10)
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594     True
# 1595     True
# 1596     True
# 1597     True
# 1598    False
# Length: 1599, dtype: bool

# %% [markdown]
# Refazendo o exemplo anterior com lógica "OU":

# %%
(dados["pH"] >= 3.4) | (dados["free sulfur dioxide"] >=10)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1594    True
# 1595    True
# 1596    True
# 1597    True
# 1598    True
# Length: 1599, dtype: bool

# %% [markdown]
# *   Podemos passar a mascara para um DataFrame e visualizar apenas as linhas onde os valores são verdadeiros pela mascara. Vamos ver os valores de dados com o filtro "pH" >3.4 e "free sulfur dioxide":

# %%
# Filtrando todo o conjunto de dados
dados[(dados["pH"] >= 3.4) & (dados["free sulfur dioxide"] >=10)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 12              5.6             0.615         0.00             1.6      0.089
# 21              7.6             0.390         0.31             2.3      0.082
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 5                    13.0                  40.0  0.99780  3.51       0.56
# 12                   16.0                  59.0  0.99430  3.58       0.52
# 21                   23.0                  71.0  0.99820  3.52       0.65
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality
# 0         9.4        5
# 4         9.4        5
# 5         9.4        5
# 12        9.9        5
# 21        9.7        5
# ...       ...      ...
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
#
# [317 rows x 12 columns]

# %% [markdown]
# Podemos também filtrar os dados a partir de colunas que especificamos e de mascaras que queremos filtrar nossos dados. Para isso, temos que usar a seguinte sintaxe `dados[["nome_coluna_1, "nome_coluna_2", ... "nome_coluna_n"],(mascara)]`. Vamos filtrar os dados pelas colunas do pH, free sulfur dioxide, quality e a nossa mascara será ph>=3.4 e free sulfur dioxide >=10:

# %%
# Filtrando apenas colunas selecionadas
dados[["pH","free sulfur dioxide", "quality"]][(dados["pH"] >= 3.4) & (dados["free sulfur dioxide"] >=10)]
# Out:
#         pH  free sulfur dioxide  quality
# 0     3.51                 11.0        5
# 4     3.51                 11.0        5
# 5     3.51                 13.0        5
# 12    3.58                 16.0        5
# 21    3.52                 23.0        5
# ...    ...                  ...      ...
# 1593  3.42                 28.0        6
# 1594  3.45                 32.0        5
# 1595  3.52                 39.0        6
# 1596  3.42                 29.0        6
# 1597  3.57                 32.0        5
#
# [317 rows x 3 columns]

# %% [markdown]
# Carregando outros dados.

# %%
# Importando o pandas
import pandas as pd

# Recebendo os dados:
from google_drive_downloader import GoogleDriveDownloader as gdd

data_google_id = '1AjWKyNferJtDY6M7-1U2u0l4dh-aOPtw'
gdd.download_file_from_google_drive(file_id=data_google_id,
                                    dest_path = './healthcare-dataset-modificado_rev_1.csv', # Faz o download dos dados e salva o mesmo num arquivo nomeado data.csv
                                    showsize = True)

# Armazenandos os dados em um DataFrame
dados_saude = pd.read_csv("healthcare-dataset-modificado_rev_1.csv", sep = ';')

# %% [markdown]
# a) as 5 primeiras linhas e as 5 últimas linhas;

# %%
dados_saude.head()
# Out:
#       X0      X1  X2   X3   X4   X5                      X6     X7    X8  \
# 0   9046    Male  67   No  Yes  Yes  five or more symptoms   22869  36.6
# 1  51676  Female  61   No   No  Yes         three symptoms   20221   NaN
# 2  31112    Male  80   No  Yes  Yes  five or more symptoms   10592  32.5
# 3  60182  Female  49   No   No  Yes  five or more symptoms   17123  34.4
# 4   1665  Female  79  Yes   No  Yes         three symptoms   17412  24.0
#
#                 X9  X10
# 0  formerly smoked  Yes
# 1     never smoked  Yes
# 2     never smoked  Yes
# 3           smokes  Yes
# 4     never smoked  Yes

# %%
dados_saude.tail()
# Out:
#          X0      X1  X2   X3  X4   X5                      X6     X7    X8  \
# 5105  18234  Female  80  Yes  No  Yes  five or more symptoms    8375   NaN
# 5106  44873  Female  81   No  No  Yes         three symptoms    1252  40.0
# 5107  19723  Female  35   No  No  Yes         three symptoms    8299  30.6
# 5108  37544    Male  51   No  No  Yes  five or more symptoms   16629  25.6
# 5109  44679  Female  44   No  No  Yes          four symptoms    8528  26.2
#
#                    X9 X10
# 5105     never smoked  No
# 5106     never smoked  No
# 5107     never smoked  No
# 5108  formerly smoked  No
# 5109          Unknown  No

# %% [markdown]
# b) os tipos de dados de cada uma das colunas;

# %%
dados_saude.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X0      5110 non-null   int64
#  1   X1      5110 non-null   object
#  2   X2      5110 non-null   int64
#  3   X3      5110 non-null   object
#  4   X4      5110 non-null   object
#  5   X5      5110 non-null   object
#  6   X6      5110 non-null   object
#  7   X7      5110 non-null   int64
#  8   X8      4909 non-null   float64
#  9   X9      5110 non-null   object
#  10  X10     5110 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 439.3+ KB

# %% [markdown]
# c) Criar um DataFrame "B" a partir de duas colunas quaisquer dos seus dados

# %%
B = dados_saude[["X2","X3"]]
B
# Out:
#       X2   X3
# 0     67   No
# 1     61   No
# 2     80   No
# 3     49   No
# 4     79  Yes
# ...   ..  ...
# 5105  80  Yes
# 5106  81   No
# 5107  35   No
# 5108  51   No
# 5109  44   No
#
# [5110 rows x 2 columns]

# %% [markdown]
# d) Criem uma mascara para filtrar os dados onde a produtividade seja maior do que 0.7

# %%
mascara = (dados_saude["X1"] == "Female") & (dados_saude["X9"] == "Unknown")
mascara
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5105    False
# 5106    False
# 5107    False
# 5108    False
# 5109     True
# Length: 5110, dtype: bool

# %%
dados_saude[mascara]["X2"]
# Out:
# 8       59
# 9       78
# 46      75
# 50      76
# 81      66
#         ..
# 5089    72
# 5101    45
# 5103    18
# 5104    13
# 5109    44
# Name: X2, Length: 836, dtype: int64
